# %%
import geopandas as gpd

# %%
gdf_u_zones = gpd.read_file('/app/data/datasets/debug/bush/sources/N_ZONE_URBA_S_034.gpkg')
gdf_u_zones

# %%
gdf_u_zones[gdf_u_zones.typezone=='U'].to_file('/app/data/datasets/debug/bush/sources/34_zones_u.gpkg', driver='GPKG')
